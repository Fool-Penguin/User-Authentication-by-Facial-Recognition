# %%
# from roboflow import Roboflow
# rf = Roboflow(api_key="T7uEFXRKxnlKwmjBGbBD")
# project = rf.workspace("kolzek").project("face-anti-spoofing-ezpqo")
# version = project.version(4)
# dataset = version.download("yolov11")

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from ultralytics import YOLO
import cv2
import numpy as np
# model = YOLO("yolov11n-face.pt") #Base model
model = YOLO("yolo11n.pt") #Base model
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 56.3MB/s 0.1s

# %%
model.info()
# Out:
# YOLO11n summary: 181 layers, 2,624,080 parameters, 0 gradients, 6.6 GFLOPs
# (181, 2624080, 0, 6.614336)

# %%
from ultralytics import YOLO
import cv2
import numpy as np
# Load YOLO model (use a face-detection weight; change path if needed)
model = YOLO('yolov11n-face.pt')
model = model.train(data="Face-Anti-Spoofing-4/data.yaml",epochs=100,batch=16,imgsz=320,device=0,lr0=0.003,patience=10,freeze=10)  # Set model to training mode
# Out:
# Ultralytics 8.3.223  Python-3.13.7 torch-2.9.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 6144MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=Face-Anti-Spoofing-4/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=10, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=320, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.003, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov11n-face.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\gifly\Desktop\Playground\User-Authentication-by-Facial-Recognition\runs\detect\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=1 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431062  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,230 parameters, 2,590,214 gradients, 6.4 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.0.conv.weight'
# Freezing layer 'model.0.bn.weight'
# Freezing layer 'model.0.bn.bias'
# Freezing layer 'model.1.conv.weight'
# Freezing layer 'model.1.bn.weight'
# Freezing layer 'model.1.bn.bias'
# Freezing layer 'model.2.cv1.conv.weight'
# Freezing layer 'model.2.cv1.bn.weight'
# Freezing layer 'model.2.cv1.bn.bias'
# Freezing layer 'model.2.cv2.conv.weight'
# Freezing layer 'model.2.cv2.bn.weight'
# Freezing layer 'model.2.cv2.bn.bias'
# Freezing layer 'model.2.m.0.cv1.conv.weight'
# Freezing layer 'model.2.m.0.cv1.bn.weight'
# Freezing layer 'model.2.m.0.cv1.bn.bias'
# Freezing layer 'model.2.m.0.cv2.conv.weight'
# Freezing layer 'model.2.m.0.cv2.bn.weight'
# Freezing layer 'model.2.m.0.cv2.bn.bias'
# Freezing layer 'model.3.conv.weight'
# Freezing layer 'model.3.bn.weight'
# Freezing layer 'model.3.bn.bias'
# Freezing layer 'model.4.cv1.conv.weight'
# Freezing layer 'model.4.cv1.bn.weight'
# Freezing layer 'model.4.cv1.bn.bias'
# Freezing layer 'model.4.cv2.conv.weight'
# Freezing layer 'model.4.cv2.bn.weight'
# Freezing layer 'model.4.cv2.bn.bias'
# Freezing layer 'model.4.m.0.cv1.conv.weight'
# Freezing layer 'model.4.m.0.cv1.bn.weight'
# Freezing layer 'model.4.m.0.cv1.bn.bias'
# Freezing layer 'model.4.m.0.cv2.conv.weight'
# Freezing layer 'model.4.m.0.cv2.bn.weight'
# Freezing layer 'model.4.m.0.cv2.bn.bias'
# Freezing layer 'model.5.conv.weight'
# Freezing layer 'model.5.bn.weight'
# Freezing layer 'model.5.bn.bias'
# Freezing layer 'model.6.cv1.conv.weight'
# Freezing layer 'model.6.cv1.bn.weight'
# Freezing layer 'model.6.cv1.bn.bias'
# Freezing layer 'model.6.cv2.conv.weight'
# Freezing layer 'model.6.cv2.bn.weight'
# Freezing layer 'model.6.cv2.bn.bias'
# Freezing layer 'model.6.m.0.cv1.conv.weight'
# Freezing layer 'model.6.m.0.cv1.bn.weight'
# Freezing layer 'model.6.m.0.cv1.bn.bias'
# Freezing layer 'model.6.m.0.cv2.conv.weight'
# Freezing layer 'model.6.m.0.cv2.bn.weight'
# Freezing layer 'model.6.m.0.cv2.bn.bias'
# Freezing layer 'model.6.m.0.cv3.conv.weight'
# Freezing layer 'model.6.m.0.cv3.bn.weight'
# Freezing layer 'model.6.m.0.cv3.bn.bias'
# Freezing layer 'model.6.m.0.m.0.cv1.conv.weight'
# Freezing layer 'model.6.m.0.m.0.cv1.bn.weight'
# Freezing layer 'model.6.m.0.m.0.cv1.bn.bias'
# Freezing layer 'model.6.m.0.m.0.cv2.conv.weight'
# Freezing layer 'model.6.m.0.m.0.cv2.bn.weight'
# Freezing layer 'model.6.m.0.m.0.cv2.bn.bias'
# Freezing layer 'model.6.m.0.m.1.cv1.conv.weight'
# Freezing layer 'model.6.m.0.m.1.cv1.bn.weight'
# Freezing layer 'model.6.m.0.m.1.cv1.bn.bias'
# Freezing layer 'model.6.m.0.m.1.cv2.conv.weight'
# Freezing layer 'model.6.m.0.m.1.cv2.bn.weight'
# Freezing layer 'model.6.m.0.m.1.cv2.bn.bias'
# Freezing layer 'model.7.conv.weight'
# Freezing layer 'model.7.bn.weight'
# Freezing layer 'model.7.bn.bias'
# Freezing layer 'model.8.cv1.conv.weight'
# Freezing layer 'model.8.cv1.bn.weight'
# Freezing layer 'model.8.cv1.bn.bias'
# Freezing layer 'model.8.cv2.conv.weight'
# Freezing layer 'model.8.cv2.bn.weight'
# Freezing layer 'model.8.cv2.bn.bias'
# Freezing layer 'model.8.m.0.cv1.conv.weight'
# Freezing layer 'model.8.m.0.cv1.bn.weight'
# Freezing layer 'model.8.m.0.cv1.bn.bias'
# Freezing layer 'model.8.m.0.cv2.conv.weight'
# Freezing layer 'model.8.m.0.cv2.bn.weight'
# Freezing layer 'model.8.m.0.cv2.bn.bias'
# Freezing layer 'model.8.m.0.cv3.conv.weight'
# Freezing layer 'model.8.m.0.cv3.bn.weight'
# Freezing layer 'model.8.m.0.cv3.bn.bias'
# Freezing layer 'model.8.m.0.m.0.cv1.conv.weight'
# Freezing layer 'model.8.m.0.m.0.cv1.bn.weight'
# Freezing layer 'model.8.m.0.m.0.cv1.bn.bias'
# Freezing layer 'model.8.m.0.m.0.cv2.conv.weight'
# Freezing layer 'model.8.m.0.m.0.cv2.bn.weight'
# Freezing layer 'model.8.m.0.m.0.cv2.bn.bias'
# Freezing layer 'model.8.m.0.m.1.cv1.conv.weight'
# Freezing layer 'model.8.m.0.m.1.cv1.bn.weight'
# Freezing layer 'model.8.m.0.m.1.cv1.bn.bias'
# Freezing layer 'model.8.m.0.m.1.cv2.conv.weight'
# Freezing layer 'model.8.m.0.m.1.cv2.bn.weight'
# Freezing layer 'model.8.m.0.m.1.cv2.bn.bias'
# Freezing layer 'model.9.cv1.conv.weight'
# Freezing layer 'model.9.cv1.bn.weight'
# Freezing layer 'model.9.cv1.bn.bias'
# Freezing layer 'model.9.cv2.conv.weight'
# Freezing layer 'model.9.cv2.bn.weight'
# Freezing layer 'model.9.cv2.bn.bias'
# Freezing layer 'model.23.dfl.conv.weight'
# WARNING AMP: checks failed . AMP training on NVIDIA GeForce GTX 1660 Ti GPU may cause NaN losses or zero-mAP results, so AMP will be disabled during training.
# train: Fast image access  (ping: 0.20.1 ms, read: 81.648.8 MB/s, size: 63.2 KB)
# train: Scanning C:\Users\gifly\Desktop\Playground\User-Authentication-by-Facial-Recognition\Face-Anti-Spoofing-4\train\labels.cache... 887 images, 113 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 887/887 1.6Mit/s 0.0s0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       4 # Load YOLO model (use a face-detection weight; change path if needed)
#       5 model = YOLO('yolov11n-face.pt')
# ----> 6 model = model.train(data="Face-Anti-Spoofing-4/data.yaml",epochs=100,batch=16,imgsz=320,device=0,lr0=0.003,patience=10,freeze=10)  # Set model to training mode
#
# File c:\Users\gifly\Desktop\Playground\User-Authentication-by-Facial-Recognition\.venv\Lib\site-packages\ultralytics\engine\model.py:800, in Model.train(self, trainer, **kwargs)
#     797     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     798     self.model = self.trainer.model
# --> 800 self.trainer.train()
#     801 # Update model and cfg after training
#     802 if RANK in {-1, 0}:
#
# File c:\Users\gifly\Desktop\Playground\User-Authentication-by-Facial-Recognition\.venv\Lib\site-packages\ultralytics\engine\trainer.py:240, in BaseTrainer.train(self)
#     237         ddp_cleanup(self, str(file))
#     239 else:
# --> 240     self._do_train()
#
# File c:\Users\gifly\Desktop\Playground\User-Authentication-by-Facial-Recognition\.venv\Lib\site-packages\ultralytics\engine\trainer.py:361, in BaseTrainer._do_train(self)
#     359 if self.world_size > 1:
#     360     self._setup_ddp()
# --> 361 self._setup_train()
#     363 nb = len(self.train_loader)  # number of batches
#     364 nw = max(round(self.args.warmup_epochs * nb), 100) if self.args.warmup_epochs > 0 else -1  # warmup iterations
#
# File c:\Users\gifly\Desktop\Playground\User-Authentication-by-Facial-Recognition\.venv\Lib\site-packages\ultralytics\engine\trainer.py:320, in BaseTrainer._setup_train(self)
#     318 # Dataloaders
#     319 batch_size = self.batch_size // max(self.world_size, 1)
# --> 320 self.train_loader = self.get_dataloader(
#     321     self.data["train"], batch_size=batch_size, rank=LOCAL_RANK, mode="train"
#     322 )
#     323 # Note: When training DOTA dataset, double batch size could get OOM on images with >2000 objects.
#     324 self.test_loader = self.get_dataloader(
#     325     self.data.get("val") or self.data.get("test"),
#     326     batch_size=batch_size if self.args.task == "obb" else batch_size * 2,
#     327     rank=LOCAL_RANK,
#     328     mode="val",
#     329 )
#
# File c:\Users\gifly\Desktop\Playground\User-Authentication-by-Facial-Recognition\.venv\Lib\site-packages\ultralytics\models\yolo\detect\train.py:102, in DetectionTrainer.get_dataloader(self, dataset_path, batch_size, rank, mode)
#     100     LOGGER.warning("'rect=True' is incompatible with DataLoader shuffle, setting shuffle=False")
#     101     shuffle = False
# --> 102 return build_dataloader(
#     103     dataset,
#     104     batch=batch_size,
#     105     workers=self.args.workers if mode == "train" else self.args.workers * 2,
#     106     shuffle=shuffle,
#     107     rank=rank,
#     108     drop_last=self.args.compile and mode == "train",
#     109 )
#
# File c:\Users\gifly\Desktop\Playground\User-Authentication-by-Facial-Recognition\.venv\Lib\site-packages\ultralytics\data\build.py:324, in build_dataloader(dataset, batch, workers, shuffle, rank, drop_last, pin_memory)
#     322 generator = torch.Generator()
#     323 generator.manual_seed(6148914691236517205 + RANK)
# --> 324 return InfiniteDataLoader(
#     325     dataset=dataset,
#     326     batch_size=batch,
#     327     shuffle=shuffle and sampler is None,
#     328     num_workers=nw,
#     329     sampler=sampler,
#     330     prefetch_factor=4 if nw > 0 else None,  # increase over default 2
#     331     pin_memory=nd > 0 and pin_memory,
#     332     collate_fn=getattr(dataset, "collate_fn", None),
#     333     worker_init_fn=seed_worker,
#     334     generator=generator,
#     335     drop_last=drop_last and len(dataset) % batch != 0,
#     336 )
#
# File c:\Users\gifly\Desktop\Playground\User-Authentication-by-Facial-Recognition\.venv\Lib\site-packages\ultralytics\data\build.py:68, in InfiniteDataLoader.__init__(self, *args, **kwargs)
#      66 super().__init__(*args, **kwargs)
#      67 object.__setattr__(self, "batch_sampler", _RepeatSampler(self.batch_sampler))
# ---> 68 self.iterator = super().__iter__()
#
# File c:\Users\gifly\Desktop\Playground\User-Authentication-by-Facial-Recognition\.venv\Lib\site-packages\torch\utils\data\dataloader.py:494, in DataLoader.__iter__(self)
#     492     return self._iterator
#     493 else:
# --> 494     return self._get_iterator()
#
# File c:\Users\gifly\Desktop\Playground\User-Authentication-by-Facial-Recognition\.venv\Lib\site-packages\torch\utils\data\dataloader.py:427, in DataLoader._get_iterator(self)
#     425 else:
#     426     self.check_worker_number_rationality()
# --> 427     return _MultiProcessingDataLoaderIter(self)
#
# File c:\Users\gifly\Desktop\Playground\User-Authentication-by-Facial-Recognition\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1170, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1163 w.daemon = True
#    1164 # NB: Process.start() actually take some time as it needs to
#    1165 #     start a process and pass the arguments over via a pipe.
#    1166 #     Therefore, we only add a worker to self._workers list after
#    1167 #     it started, so that we do not call .join() if program dies
#    1168 #     before it starts, and __del__ tries to join but will get:
#    1169 #     AssertionError: can only join a started process.
# -> 1170 w.start()
#    1171 self._index_queues.append(index_queue)
#    1172 self._workers.append(w)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\context.py:337, in SpawnProcess._Popen(process_obj)
#     334 @staticmethod
#     335 def _Popen(process_obj):
#     336     from .popen_spawn_win32 import Popen
# --> 337     return Popen(process_obj)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\popen_spawn_win32.py:97, in Popen.__init__(self, process_obj)
#      95 try:
#      96     reduction.dump(prep_data, to_child)
# ---> 97     reduction.dump(process_obj, to_child)
#      98 finally:
#      99     set_spawning_popen(None)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\reduction.py:60, in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#
# KeyboardInterrupt:

# %%
#Running
from ultralytics import YOLO
import cv2
import numpy as np

# model = YOLO('yolov11n-face.pt')
model = YOLO('yolov11n-face.pt')
# Open default camera
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise SystemExit("Cannot open camera")

try:
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Run model on the BGR frame (Ultralytics accepts numpy arrays)
        results = model(frame)[0]  # results is a single Result object

        # Extract boxes, confidences, classes
        if results.boxes:
            xyxy = results.boxes.xyxy.cpu().numpy()    # shape (N,4)
            confs = results.boxes.conf.cpu().numpy()   # shape (N,)
            clss = results.boxes.cls.cpu().numpy()     # shape (N,)
            names = results.names                       # dict/list of class names

            for (x1, y1, x2, y2), conf, cls in zip(xyxy, confs, clss):
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
                label = names[int(cls)] if int(cls) in names else str(int(cls))
                text = f"{label} {conf:.2f}"
                # Draw box and label
                # cv2.rectangle(frame, (x1-50, y1-50), (x2+50, y2+50), (0, 255, 0), 3)
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 3)
                cv2.putText(frame, text, (x1, y1 - 6), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0, 255, 0), 1)

        # Show frame
        cv2.imshow("YOLO Face Detection", frame)

        # Quit on 'q'
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
finally:
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 0: 480x640 4 faces, 45.5ms
# Speed: 2.0ms preprocess, 45.5ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 16.3ms
# Speed: 3.1ms preprocess, 16.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 12.9ms
# Speed: 2.0ms preprocess, 12.9ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 15.9ms
# Speed: 1.4ms preprocess, 15.9ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 13.8ms
# Speed: 1.2ms preprocess, 13.8ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 13.5ms
# Speed: 1.5ms preprocess, 13.5ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 15.6ms
# Speed: 1.1ms preprocess, 15.6ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 26.0ms
# Speed: 1.6ms preprocess, 26.0ms inference, 8.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.2ms
# Speed: 2.1ms preprocess, 13.2ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 13.5ms
# Speed: 1.5ms preprocess, 13.5ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 13.3ms
# Speed: 1.7ms preprocess, 13.3ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 27.4ms
# Speed: 2.3ms preprocess, 27.4ms inference, 9.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 22.2ms
# Speed: 2.4ms preprocess, 22.2ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 faces, 22.1ms
# Speed: 2.2ms preprocess, 22.1ms inference, 9.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 13.4ms
# Speed: 1.4ms preprocess, 13.4ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.0ms
# Speed: 1.2ms preprocess, 13.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.9ms
# Speed: 1.3ms preprocess, 12.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.9ms
# Speed: 1.3ms preprocess, 12.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 16.1ms
# Speed: 1.3ms preprocess, 16.1ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 12.7ms
# Speed: 2.1ms preprocess, 12.7ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 15.0ms
# Speed: 1.5ms preprocess, 15.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 21.9ms
# Speed: 1.5ms preprocess, 21.9ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 13.7ms
# Speed: 2.3ms preprocess, 13.7ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.0ms
# Speed: 1.4ms preprocess, 13.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.1ms
# Speed: 1.4ms preprocess, 13.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.9ms
# Speed: 1.5ms preprocess, 12.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 18.5ms
# Speed: 2.4ms preprocess, 18.5ms inference, 10.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 faces, 14.4ms
# Speed: 1.3ms preprocess, 14.4ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.6ms
# Speed: 1.3ms preprocess, 12.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 20.9ms
# Speed: 2.4ms preprocess, 20.9ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 15.3ms
# Speed: 1.5ms preprocess, 15.3ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 28.6ms
# Speed: 1.5ms preprocess, 28.6ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 13.3ms
# Speed: 1.3ms preprocess, 13.3ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 14.3ms
# Speed: 1.4ms preprocess, 14.3ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 13.0ms
# Speed: 1.2ms preprocess, 13.0ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 12.8ms
# Speed: 1.4ms preprocess, 12.8ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 16.5ms
# Speed: 1.3ms preprocess, 16.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 13.7ms
# Speed: 1.3ms preprocess, 13.7ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 16.3ms
# Speed: 1.2ms preprocess, 16.3ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.0ms
# Speed: 1.3ms preprocess, 13.0ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.9ms
# Speed: 1.5ms preprocess, 12.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.8ms
# Speed: 2.4ms preprocess, 13.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 13.8ms
# Speed: 2.9ms preprocess, 13.8ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.2ms
# Speed: 1.3ms preprocess, 13.2ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 15.8ms
# Speed: 1.5ms preprocess, 15.8ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 15.7ms
# Speed: 1.4ms preprocess, 15.7ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 14.8ms
# Speed: 1.4ms preprocess, 14.8ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 18.0ms
# Speed: 1.5ms preprocess, 18.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 21.3ms
# Speed: 2.8ms preprocess, 21.3ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 22.3ms
# Speed: 2.4ms preprocess, 22.3ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.3ms
# Speed: 1.5ms preprocess, 13.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 25.2ms
# Speed: 3.3ms preprocess, 25.2ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 30.6ms
# Speed: 2.7ms preprocess, 30.6ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 26.1ms
# Speed: 1.5ms preprocess, 26.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 23.0ms
# Speed: 1.3ms preprocess, 23.0ms inference, 8.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 17.8ms
# Speed: 2.4ms preprocess, 17.8ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 14.7ms
# Speed: 2.8ms preprocess, 14.7ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 14.4ms
# Speed: 1.3ms preprocess, 14.4ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.8ms
# Speed: 1.4ms preprocess, 12.8ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.9ms
# Speed: 1.3ms preprocess, 12.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.4ms
# Speed: 2.4ms preprocess, 13.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 17.9ms
# Speed: 1.5ms preprocess, 17.9ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.8ms
# Speed: 1.2ms preprocess, 13.8ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.9ms
# Speed: 1.4ms preprocess, 12.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.4ms
# Speed: 1.3ms preprocess, 13.4ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.8ms
# Speed: 1.1ms preprocess, 12.8ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 13.6ms
# Speed: 1.3ms preprocess, 13.6ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 faces, 12.8ms
# Speed: 1.3ms preprocess, 12.8ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 20.6ms
# Speed: 1.6ms preprocess, 20.6ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 12.8ms
# Speed: 1.2ms preprocess, 12.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 12.7ms
# Speed: 1.3ms preprocess, 12.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 12.7ms
# Speed: 1.5ms preprocess, 12.7ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 12.9ms
# Speed: 1.4ms preprocess, 12.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 20.2ms
# Speed: 1.3ms preprocess, 20.2ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 16.0ms
# Speed: 1.4ms preprocess, 16.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 12.9ms
# Speed: 1.4ms preprocess, 12.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.8ms
# Speed: 2.9ms preprocess, 12.8ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 22.5ms
# Speed: 1.3ms preprocess, 22.5ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 24.3ms
# Speed: 1.2ms preprocess, 24.3ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.6ms
# Speed: 1.3ms preprocess, 13.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 13.2ms
# Speed: 1.3ms preprocess, 13.2ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 12.6ms
# Speed: 1.2ms preprocess, 12.6ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 16.4ms
# Speed: 1.3ms preprocess, 16.4ms inference, 9.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 13.0ms
# Speed: 1.3ms preprocess, 13.0ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.2ms
# Speed: 1.5ms preprocess, 12.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 21.9ms
# Speed: 1.2ms preprocess, 21.9ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 faces, 12.1ms
# Speed: 2.2ms preprocess, 12.1ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 faces, 23.2ms
# Speed: 1.2ms preprocess, 23.2ms inference, 9.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 14.6ms
# Speed: 1.6ms preprocess, 14.6ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 22.5ms
# Speed: 1.4ms preprocess, 22.5ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 23.9ms
# Speed: 2.5ms preprocess, 23.9ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 22.2ms
# Speed: 3.1ms preprocess, 22.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 17.6ms
# Speed: 2.3ms preprocess, 17.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 24.1ms
# Speed: 1.7ms preprocess, 24.1ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 21.2ms
# Speed: 1.3ms preprocess, 21.2ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 14.1ms
# Speed: 1.3ms preprocess, 14.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.3ms
# Speed: 1.3ms preprocess, 13.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.5ms
# Speed: 1.3ms preprocess, 12.5ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 21.4ms
# Speed: 1.3ms preprocess, 21.4ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 23.9ms
# Speed: 1.4ms preprocess, 23.9ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 19.4ms
# Speed: 1.9ms preprocess, 19.4ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.0ms
# Speed: 1.3ms preprocess, 13.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 19.1ms
# Speed: 2.4ms preprocess, 19.1ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 17.5ms
# Speed: 1.8ms preprocess, 17.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.2ms
# Speed: 1.3ms preprocess, 13.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.9ms
# Speed: 1.2ms preprocess, 13.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 12.9ms
# Speed: 1.3ms preprocess, 12.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 12.8ms
# Speed: 2.0ms preprocess, 12.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 12.7ms
# Speed: 1.4ms preprocess, 12.7ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 15.0ms
# Speed: 1.4ms preprocess, 15.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 13.0ms
# Speed: 1.3ms preprocess, 13.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 12.4ms
# Speed: 2.2ms preprocess, 12.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 17.0ms
# Speed: 1.4ms preprocess, 17.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 21.7ms
# Speed: 1.3ms preprocess, 21.7ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.2ms
# Speed: 1.3ms preprocess, 13.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.4ms
# Speed: 1.4ms preprocess, 12.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 14.1ms
# Speed: 1.2ms preprocess, 14.1ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 23.8ms
# Speed: 1.5ms preprocess, 23.8ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 14.0ms
# Speed: 1.3ms preprocess, 14.0ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 20.8ms
# Speed: 1.4ms preprocess, 20.8ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 24.2ms
# Speed: 1.5ms preprocess, 24.2ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 24.6ms
# Speed: 1.6ms preprocess, 24.6ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 24.2ms
# Speed: 1.3ms preprocess, 24.2ms inference, 8.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 23.9ms
# Speed: 1.3ms preprocess, 23.9ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 24.7ms
# Speed: 1.3ms preprocess, 24.7ms inference, 8.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 12.4ms
# Speed: 2.4ms preprocess, 12.4ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 12.4ms
# Speed: 1.3ms preprocess, 12.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 12.9ms
# Speed: 1.2ms preprocess, 12.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 13.1ms
# Speed: 1.2ms preprocess, 13.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 13.0ms
# Speed: 1.8ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 12.1ms
# Speed: 1.3ms preprocess, 12.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 13.1ms
# Speed: 1.3ms preprocess, 13.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 26.4ms
# Speed: 1.7ms preprocess, 26.4ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 32.3ms
# Speed: 2.2ms preprocess, 32.3ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 16.3ms
# Speed: 1.3ms preprocess, 16.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 26.3ms
# Speed: 1.5ms preprocess, 26.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 12.8ms
# Speed: 1.1ms preprocess, 12.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 14.0ms
# Speed: 1.4ms preprocess, 14.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 22.3ms
# Speed: 1.3ms preprocess, 22.3ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 13.4ms
# Speed: 1.5ms preprocess, 13.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 13.3ms
# Speed: 1.4ms preprocess, 13.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 26.6ms
# Speed: 1.6ms preprocess, 26.6ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 17.2ms
# Speed: 1.2ms preprocess, 17.2ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 13.6ms
# Speed: 1.8ms preprocess, 13.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 27.0ms
# Speed: 1.4ms preprocess, 27.0ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 12.2ms
# Speed: 1.2ms preprocess, 12.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 13.4ms
# Speed: 2.6ms preprocess, 13.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 15.9ms
# Speed: 1.7ms preprocess, 15.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 20.5ms
# Speed: 1.7ms preprocess, 20.5ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 12.8ms
# Speed: 1.3ms preprocess, 12.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.0ms
# Speed: 1.2ms preprocess, 22.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.7ms
# Speed: 1.7ms preprocess, 13.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.5ms
# Speed: 1.3ms preprocess, 14.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.1ms
# Speed: 3.0ms preprocess, 24.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.0ms
# Speed: 1.3ms preprocess, 13.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.2ms
# Speed: 1.4ms preprocess, 24.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 12.7ms
# Speed: 1.4ms preprocess, 12.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 13.4ms
# Speed: 1.4ms preprocess, 13.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 13.2ms
# Speed: 1.3ms preprocess, 13.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 16.0ms
# Speed: 1.3ms preprocess, 16.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 12.8ms
# Speed: 1.4ms preprocess, 12.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 23.5ms
# Speed: 1.4ms preprocess, 23.5ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 12.8ms
# Speed: 2.1ms preprocess, 12.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 13.4ms
# Speed: 1.3ms preprocess, 13.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 face, 21.8ms
# Speed: 1.4ms preprocess, 21.8ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 13.7ms
# Speed: 1.4ms preprocess, 13.7ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 17.0ms
# Speed: 1.4ms preprocess, 17.0ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 23.4ms
# Speed: 1.4ms preprocess, 23.4ms inference, 8.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 22.5ms
# Speed: 1.3ms preprocess, 22.5ms inference, 10.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 12.8ms
# Speed: 1.2ms preprocess, 12.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 21.5ms
# Speed: 1.4ms preprocess, 21.5ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 24.0ms
# Speed: 2.8ms preprocess, 24.0ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 24.3ms
# Speed: 2.1ms preprocess, 24.3ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 18.5ms
# Speed: 2.5ms preprocess, 18.5ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.9ms
# Speed: 1.3ms preprocess, 13.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.7ms
# Speed: 1.8ms preprocess, 13.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.9ms
# Speed: 1.4ms preprocess, 12.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 18.5ms
# Speed: 1.6ms preprocess, 18.5ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.5ms
# Speed: 1.7ms preprocess, 12.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.6ms
# Speed: 1.5ms preprocess, 12.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.8ms
# Speed: 1.3ms preprocess, 12.8ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.2ms
# Speed: 1.3ms preprocess, 13.2ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 13.8ms
# Speed: 1.4ms preprocess, 13.8ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 26.7ms
# Speed: 1.8ms preprocess, 26.7ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 14.5ms
# Speed: 1.4ms preprocess, 14.5ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.2ms
# Speed: 1.4ms preprocess, 13.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 15.4ms
# Speed: 1.9ms preprocess, 15.4ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 17.8ms
# Speed: 1.8ms preprocess, 17.8ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 21.3ms
# Speed: 2.3ms preprocess, 21.3ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.7ms
# Speed: 1.2ms preprocess, 12.7ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.5ms
# Speed: 1.2ms preprocess, 13.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 23.0ms
# Speed: 1.7ms preprocess, 23.0ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 22.1ms
# Speed: 1.3ms preprocess, 22.1ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.5ms
# Speed: 1.4ms preprocess, 13.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 14.3ms
# Speed: 2.6ms preprocess, 14.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.4ms
# Speed: 1.3ms preprocess, 13.4ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 23.3ms
# Speed: 1.4ms preprocess, 23.3ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.7ms
# Speed: 2.4ms preprocess, 12.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 faces, 21.8ms
# Speed: 1.5ms preprocess, 21.8ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.0ms
# Speed: 1.2ms preprocess, 13.0ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 19.0ms
# Speed: 1.3ms preprocess, 19.0ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.7ms
# Speed: 1.3ms preprocess, 13.7ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 15.3ms
# Speed: 1.3ms preprocess, 15.3ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.8ms
# Speed: 1.3ms preprocess, 12.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.1ms
# Speed: 1.3ms preprocess, 13.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.4ms
# Speed: 1.3ms preprocess, 13.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.2ms
# Speed: 1.9ms preprocess, 12.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.6ms
# Speed: 1.3ms preprocess, 12.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 23.3ms
# Speed: 1.6ms preprocess, 23.3ms inference, 9.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 26.4ms
# Speed: 2.5ms preprocess, 26.4ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 17.7ms
# Speed: 2.7ms preprocess, 17.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 25.2ms
# Speed: 1.4ms preprocess, 25.2ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.3ms
# Speed: 1.8ms preprocess, 13.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 23.7ms
# Speed: 1.8ms preprocess, 23.7ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.3ms
# Speed: 1.3ms preprocess, 13.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.7ms
# Speed: 1.7ms preprocess, 12.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.6ms
# Speed: 1.1ms preprocess, 12.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.0ms
# Speed: 1.4ms preprocess, 13.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 25.2ms
# Speed: 1.4ms preprocess, 25.2ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 23.0ms
# Speed: 1.4ms preprocess, 23.0ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.6ms
# Speed: 1.9ms preprocess, 12.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.8ms
# Speed: 1.3ms preprocess, 12.8ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.6ms
# Speed: 1.2ms preprocess, 12.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.1ms
# Speed: 1.7ms preprocess, 12.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 24.0ms
# Speed: 1.4ms preprocess, 24.0ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 14.0ms
# Speed: 1.5ms preprocess, 14.0ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.9ms
# Speed: 1.8ms preprocess, 12.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 23.6ms
# Speed: 1.8ms preprocess, 23.6ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.1ms
# Speed: 1.7ms preprocess, 12.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.6ms
# Speed: 1.2ms preprocess, 12.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 22.4ms
# Speed: 1.8ms preprocess, 22.4ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 14.2ms
# Speed: 1.3ms preprocess, 14.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.7ms
# Speed: 2.1ms preprocess, 13.7ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.0ms
# Speed: 1.4ms preprocess, 13.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 21.7ms
# Speed: 1.5ms preprocess, 21.7ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.8ms
# Speed: 1.7ms preprocess, 13.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.1ms
# Speed: 1.9ms preprocess, 13.1ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 18.6ms
# Speed: 1.2ms preprocess, 18.6ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 19.9ms
# Speed: 1.4ms preprocess, 19.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.7ms
# Speed: 1.4ms preprocess, 12.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.6ms
# Speed: 1.8ms preprocess, 12.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.1ms
# Speed: 1.7ms preprocess, 13.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.4ms
# Speed: 1.4ms preprocess, 12.4ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.8ms
# Speed: 1.4ms preprocess, 12.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.4ms
# Speed: 1.2ms preprocess, 12.4ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.3ms
# Speed: 1.3ms preprocess, 13.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.2ms
# Speed: 1.6ms preprocess, 12.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.6ms
# Speed: 1.2ms preprocess, 12.6ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 22.8ms
# Speed: 2.3ms preprocess, 22.8ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 24.8ms
# Speed: 2.6ms preprocess, 24.8ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 19.8ms
# Speed: 1.6ms preprocess, 19.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 24.7ms
# Speed: 2.0ms preprocess, 24.7ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.9ms
# Speed: 1.3ms preprocess, 12.9ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.0ms
# Speed: 1.3ms preprocess, 13.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.8ms
# Speed: 1.6ms preprocess, 12.8ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.0ms
# Speed: 1.5ms preprocess, 13.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.7ms
# Speed: 1.8ms preprocess, 12.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.6ms
# Speed: 1.4ms preprocess, 12.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.6ms
# Speed: 1.2ms preprocess, 12.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.3ms
# Speed: 1.5ms preprocess, 12.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 13.2ms
# Speed: 1.7ms preprocess, 13.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.1ms
# Speed: 1.2ms preprocess, 12.1ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 21.3ms
# Speed: 1.6ms preprocess, 21.3ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.5ms
# Speed: 1.2ms preprocess, 12.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 faces, 12.7ms
# Speed: 1.6ms preprocess, 12.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
