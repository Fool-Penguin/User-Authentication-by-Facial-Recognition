# %%
# file_path = "FullDB/Peem3.jpg"
# deepface = DeepFaceAntiSpoofing()
# response = deepface.analyze_image(file_path)
# print(f"{response['dominant_spoof']}")  # True for spoofed, False for real

# %%
from deepface_antispoofing import DeepFaceAntiSpoofing
file_path = "FullDB/Peem3.jpg"
deepface = DeepFaceAntiSpoofing()
response = deepface.analyze_image(file_path)
print(f"{response['dominant_spoof']}")  # True for spoofed,
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 5
#       3 deepface = DeepFaceAntiSpoofing()
#       4 response = deepface.analyze_image(file_path)
# ----> 5 print(f"{response['dominant_spoof']}")  # True for spoofed,
#
# KeyError: 'dominant_spoof'
